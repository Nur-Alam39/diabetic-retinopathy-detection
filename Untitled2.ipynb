# %%
import os
import pandas as pd
import sys
# from PIL import Image
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True
from skimage import io
from skimage.transform import resize
import numpy as np


def create_directory(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)


def move_image(path, new_path):
    create_directory(new_path)
    trainLabels = pd.read_csv("H:/Thesis/[4-2]/Dataset/trainLabels.csv")
    trainLabels['image'] = trainLabels['image'].str.rstrip('.jpeg')
    trainLabels_3 = trainLabels[trainLabels['level'] == 4]
    lst_imgs_3 = [i for i in trainLabels_3['image']]
    total = 0

    for item in lst_imgs_3:
        img = io.imread(path+item+".jpeg")
        io.imsave(str(new_path + item+".jpeg"), img)
        total += 1
        os.remove(path+item+".jpeg")
        print("Moved and Deleted: ", item, total)


if __name__ == '__main__':
    move_image(path='H:/Thesis/[4-2]/Dataset/train/', new_path='H:/Thesis/[4-2]/Dataset/train/four/')
# Out:
# Moved and Deleted:  32230_right 1
# Moved and Deleted:  32630_left 2
# Moved and Deleted:  32630_right 3
# Moved and Deleted:  32846_left 4
# Moved and Deleted:  32846_right 5
# Moved and Deleted:  32851_right 6
# Moved and Deleted:  32868_left 7
# Moved and Deleted:  32868_right 8
# Moved and Deleted:  33003_left 9
# Moved and Deleted:  33080_left 10
# Moved and Deleted:  33080_right 11
# Moved and Deleted:  33236_left 12
# Moved and Deleted:  33236_right 13
# Moved and Deleted:  33270_left 14
# Moved and Deleted:  33283_left 15
# Moved and Deleted:  33283_right 16
# Moved and Deleted:  33287_left 17
# Moved and Deleted:  33358_right 18
# Moved and Deleted:  33493_left 19
# Moved and Deleted:  33493_right 20
# Moved and Deleted:  33580_left 21
# Moved and Deleted:  33621_left 22
# Moved and Deleted:  33621_right 23
# Moved and Deleted:  33725_left 24
# Moved and Deleted:  33725_right 25
# Moved and Deleted:  33753_left 26
# Moved and Deleted:  33812_right 27
# Moved and Deleted:  33884_left 28
# Moved and Deleted:  33884_right 29
# Moved and Deleted:  33906_left 30
# Moved and Deleted:  33906_right 31
# Moved and Deleted:  34152_left 32
# Moved and Deleted:  34152_right 33
# Moved and Deleted:  34400_left 34
# Moved and Deleted:  34400_right 35
# Moved and Deleted:  34453_left 36
# Moved and Deleted:  34453_right 37
# Moved and Deleted:  34708_left 38
# Moved and Deleted:  34708_right 39
# Moved and Deleted:  34844_left 40
# Moved and Deleted:  34844_right 41
# Moved and Deleted:  34901_left 42
# Moved and Deleted:  34901_right 43
# Moved and Deleted:  34995_left 44
# Moved and Deleted:  34995_right 45
# Moved and Deleted:  35112_left 46
# Moved and Deleted:  35112_right 47
# Moved and Deleted:  35130_left 48
# Moved and Deleted:  35130_right 49
# Moved and Deleted:  35199_right 50
# Moved and Deleted:  35323_right 51
# Moved and Deleted:  35412_left 52
# Moved and Deleted:  35461_left 53
# Moved and Deleted:  35461_right 54
# Moved and Deleted:  35668_left 55
# Moved and Deleted:  35668_right 56
# Moved and Deleted:  35704_left 57
# Moved and Deleted:  35704_right 58
# Moved and Deleted:  35766_left 59
# Moved and Deleted:  35766_right 60
# Moved and Deleted:  35804_left 61
# Moved and Deleted:  35804_right 62
# Moved and Deleted:  35861_left 63
# Moved and Deleted:  35861_right 64
# Moved and Deleted:  35955_left 65
# Moved and Deleted:  35955_right 66
# Moved and Deleted:  36027_right 67
# Moved and Deleted:  36074_left 68
# Moved and Deleted:  36125_left 69
# Moved and Deleted:  36166_right 70
# Moved and Deleted:  36258_left 71
# Moved and Deleted:  36258_right 72
# Moved and Deleted:  36300_right 73
# Moved and Deleted:  36453_left 74
# Moved and Deleted:  36453_right 75
# Moved and Deleted:  36531_left 76
# Moved and Deleted:  36640_left 77
# Moved and Deleted:  36640_right 78
# Moved and Deleted:  36653_left 79
# Moved and Deleted:  36653_right 80
# Moved and Deleted:  36722_right 81
# Moved and Deleted:  36832_right 82
# Moved and Deleted:  37008_left 83
# Moved and Deleted:  37008_right 84
# Moved and Deleted:  37117_left 85
# Moved and Deleted:  37117_right 86
# Moved and Deleted:  37232_left 87
# Moved and Deleted:  37332_left 88
# Moved and Deleted:  37332_right 89
# Moved and Deleted:  37438_left 90
# Moved and Deleted:  37708_left 91
# Moved and Deleted:  37708_right 92
# Moved and Deleted:  37783_left 93
# Moved and Deleted:  37783_right 94
# Moved and Deleted:  37808_left 95
# Moved and Deleted:  37808_right 96
# Moved and Deleted:  37813_left 97
# Moved and Deleted:  37813_right 98
# Moved and Deleted:  37829_left 99
# Moved and Deleted:  37834_left 100
# Moved and Deleted:  37834_right 101
# Moved and Deleted:  37849_left 102
# Moved and Deleted:  37849_right 103
# Moved and Deleted:  37951_left 104
# Moved and Deleted:  37951_right 105
# Moved and Deleted:  37958_left 106
# Moved and Deleted:  37962_left 107
# Moved and Deleted:  38064_left 108
# Moved and Deleted:  38064_right 109
# Moved and Deleted:  38186_left 110
# Moved and Deleted:  38186_right 111
# Moved and Deleted:  38325_left 112
# Moved and Deleted:  38325_right 113
# Moved and Deleted:  38345_left 114
# Moved and Deleted:  38407_left 115
# Moved and Deleted:  38407_right 116
# Moved and Deleted:  38513_left 117
# Moved and Deleted:  38513_right 118
# Moved and Deleted:  38518_left 119
# Moved and Deleted:  38518_right 120
# Moved and Deleted:  38595_right 121
# Moved and Deleted:  38653_left 122
# Moved and Deleted:  38662_left 123
# Moved and Deleted:  38811_left 124
# Moved and Deleted:  38811_right 125
# Moved and Deleted:  38856_left 126
# Moved and Deleted:  38856_right 127
# Moved and Deleted:  39081_right 128
# Moved and Deleted:  39134_right 129
# Moved and Deleted:  39164_left 130
# Moved and Deleted:  39164_right 131
# Moved and Deleted:  39188_left 132
# Moved and Deleted:  39188_right 133
# Moved and Deleted:  39353_right 134
# Moved and Deleted:  39505_left 135
# Moved and Deleted:  39505_right 136
# Moved and Deleted:  39741_left 137
# Moved and Deleted:  39741_right 138
# Moved and Deleted:  39747_left 139
# Moved and Deleted:  39747_right 140
# Moved and Deleted:  39772_right 141
# Moved and Deleted:  40078_left 142
# Moved and Deleted:  40178_left 143
# Moved and Deleted:  40178_right 144
# Moved and Deleted:  40183_left 145
# Moved and Deleted:  40183_right 146
# Moved and Deleted:  40319_right 147
# Moved and Deleted:  40323_left 148
# Moved and Deleted:  40323_right 149
# Moved and Deleted:  40405_right 150
# Moved and Deleted:  40673_left 151
# Moved and Deleted:  40673_right 152
# Moved and Deleted:  40819_left 153
# Moved and Deleted:  40819_right 154
# Moved and Deleted:  40893_left 155
# Moved and Deleted:  40893_right 156
# Moved and Deleted:  40917_left 157
# Moved and Deleted:  40940_left 158
# Moved and Deleted:  41174_left 159
# Moved and Deleted:  41174_right 160
# Moved and Deleted:  41201_left 161
# Moved and Deleted:  41201_right 162
# Moved and Deleted:  41339_left 163
# Moved and Deleted:  41339_right 164
# Moved and Deleted:  41387_left 165
# Moved and Deleted:  41387_right 166
# Moved and Deleted:  41430_left 167
# Moved and Deleted:  41430_right 168
# Moved and Deleted:  41445_left 169
# Moved and Deleted:  41445_right 170
# Moved and Deleted:  41584_left 171
# Moved and Deleted:  41584_right 172
# Moved and Deleted:  41746_left 173
# Moved and Deleted:  41746_right 174
# Moved and Deleted:  41761_left 175
# Moved and Deleted:  41761_right 176
# Moved and Deleted:  41852_right 177
# Moved and Deleted:  42022_right 178
# Moved and Deleted:  42316_left 179
# Moved and Deleted:  42358_left 180
# Moved and Deleted:  42442_right 181
# Moved and Deleted:  42484_left 182
# Moved and Deleted:  42484_right 183
# Moved and Deleted:  42815_left 184
# Moved and Deleted:  42815_right 185
# Moved and Deleted:  43008_left 186
# Moved and Deleted:  43050_left 187
# Moved and Deleted:  43050_right 188
# Moved and Deleted:  43141_left 189
# Moved and Deleted:  43141_right 190
# Moved and Deleted:  43199_left 191
# Moved and Deleted:  43199_right 192
# Moved and Deleted:  43339_left 193
# Moved and Deleted:  43339_right 194
# Moved and Deleted:  43379_left 195
# Moved and Deleted:  43379_right 196
# Moved and Deleted:  43839_right 197
# Moved and Deleted:  43997_left 198
# Moved and Deleted:  43997_right 199
# Moved and Deleted:  43998_left 200
# Moved and Deleted:  44100_left 201
# Moved and Deleted:  44247_left 202
# Moved and Deleted:  44247_right 203
# Moved and Deleted:  44249_left 204
# Moved and Deleted:  44249_right 205
